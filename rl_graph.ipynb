# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./mean_std_iter_100.csv',header=0,names=['QL error', 'SQL error','QL std', 'SQL std'])

# %%
df
# Out:
#        QL error  SQL error    QL std   SQL std
# 0      3.064148   3.064148  0.391339  0.391339
# 1      3.045072   3.043911  0.387420  0.386962
# 2      3.035688   3.033753  0.386110  0.385460
# 3      3.034732   3.032500  0.385199  0.384894
# 4      3.022656   3.020405  0.385349  0.385073
# ...         ...        ...       ...       ...
# 99994  2.445441   2.257304  0.347631  0.346638
# 99995  2.445441   2.257305  0.347631  0.346638
# 99996  2.445441   2.257305  0.347631  0.346638
# 99997  2.445441   2.257305  0.347631  0.346638
# 99998  2.445441   2.257305  0.347631  0.346638
#
# [99999 rows x 4 columns]

# %%
plt.rcParams.update({'font.size': 22})
df.plot( y=['QL error', 'SQL error'],use_index=True,
        kind="line", figsize=(10, 10))

plt.xlabel('iteration')
plt.ylabel('error: ||V* - Vk||')
# Out:
# Text(0, 0.5, 'error: ||V* - Vk||')

# %%
df.plot( y=['QL std', 'SQL std'],use_index=True,
        kind="line", figsize=(10, 10))

plt.xlabel('iterations')
plt.ylabel('std')
# Out:
# Text(0, 0.5, 'std')

# %%
df=pd.read_csv('./linear_statistics.csv',header=0,names=['epoch','train_loss','train_acc@1','train_acc@5','test_loss','test_acc@1','test_acc@5'])

# %%
df
# Out:
#     epoch  train_loss  train_acc@1  train_acc@5  test_loss  test_acc@1  \
# 0       1    0.918446       72.726       97.128   0.541595       81.88
# 1       2    0.679474       76.578       98.092   0.486964       83.42
# 2       3    0.653766       77.368       98.182   0.459553       84.15
# 3       4    0.639145       77.720       98.250   0.447546       84.42
# 4       5    0.632140       78.096       98.268   0.438629       84.58
# ..    ...         ...          ...          ...        ...         ...
# 95     96    0.571210       80.170       98.482   0.366541       87.28
# 96     97    0.568889       80.060       98.516   0.366075       87.08
# 97     98    0.569300       80.320       98.500   0.367695       87.20
# 98     99    0.566045       80.168       98.434   0.365953       87.13
# 99    100    0.566904       80.392       98.444   0.363840       87.28
#
#     test_acc@5
# 0        99.24
# 1        99.48
# 2        99.50
# 3        99.51
# 4        99.50
# ..         ...
# ...

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@5','test_acc@5'],use_index=True,
        kind="line", figsize=(5, 5))
plt.title('Linear \'g\' (SimCLR) Top@5')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@1','test_acc@1'],use_index=True,
        kind="line", figsize=(5, 5))

plt.title('Linear \'g\' (SimCLR) Top@1')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
df=pd.read_csv('./linear_statistics_supervised.csv',header=0,names=['epoch','train_loss','train_acc@1','train_acc@5','test_loss','test_acc@1','test_acc@5'])

# %%
df
# Out:
#     epoch  train_loss  train_acc@1  train_acc@5  test_loss  test_acc@1  \
# 0       1    2.367476       12.522       55.476   2.286932       18.87
# 1       2    2.308879       14.494       60.208   2.287336       15.00
# 2       3    2.295249       15.518       61.886   2.270209       15.97
# 3       4    2.272866       16.402       63.308   2.230778       19.66
# 4       5    2.278511       16.704       63.522   2.274190       21.31
# ..    ...         ...          ...          ...        ...         ...
# 95     96    2.200612       19.792       69.756   2.202658       21.27
# 96     97    2.200649       20.130       69.760   2.261268       19.89
# 97     98    2.200644       20.062       69.834   2.159561       23.54
# 98     99    2.192084       20.030       70.094   2.083518       24.80
# 99    100    2.195145       20.002       70.038   2.231514       20.53
#
#     test_acc@5
# 0        65.73
# 1        65.32
# 2        65.74
# 3        67.49
# 4        66.69
# ..         ...
# ...

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@5','test_acc@5'],use_index=True,
        kind="line", figsize=(5, 5))
plt.title('Supervised Top@5')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@1','test_acc@1'],use_index=True,
        kind="line", figsize=(5, 5))

plt.title('Supervised Top@1')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
file1 = './128_0.5_200_128_100_statistics.csv'
df=pd.read_csv(file1,header=0,names=['epoch','train_loss','test_acc@1','test_acc@5'])

# %%
df
# Out:
#     epoch  train_loss  test_acc@1  test_acc@5
# 0       1    4.039065       77.80       98.96
# 1       2    4.030211       78.05       98.96
# 2       3    4.026478       78.59       98.92
# 3       4    4.027788       77.86       98.96
# 4       5    4.021952       78.54       98.91
# ..    ...         ...         ...         ...
# 70     71    3.990169       81.26       99.28
# 71     72    3.984228       81.56       99.35
# 72     73    3.984238       81.40       99.30
# 73     74    3.984515       81.50       99.18
# 74     75    3.984045       81.31       99.28
#
# [75 rows x 4 columns]

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['test_acc@1','test_acc@5'],use_index=True,
        kind="line", figsize=(5, 5))
plt.title('SimCLR accuracy(while training)')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
df=pd.read_csv('./linear_statistics_supervised_output_normalized.csv',header=0,names=['epoch','train_loss','train_acc@1','train_acc@5','test_loss','test_acc@1','test_acc@5'])

# %%
df
# Out:
#     epoch  train_loss  train_acc@1  train_acc@5  test_loss  test_acc@1  \
# 0       1    2.292615       12.050       55.500   2.259860       15.70
# 1       2    2.282369       12.738       57.836   2.258375       15.26
# 2       3    2.273935       13.676       59.386   2.250550       15.89
# 3       4    2.267860       14.308       60.638   2.260759       15.01
# 4       5    2.253729       15.670       62.846   2.209952       20.50
# ..    ...         ...          ...          ...        ...         ...
# 95     96    2.182006       21.376       71.370   2.170513       22.86
# 96     97    2.185228       20.870       70.868   2.134767       26.31
# 97     98    2.182855       21.010       71.230   2.132072       26.42
# 98     99    2.182311       21.384       71.308   2.164250       22.00
# 99    100    2.182959       21.022       71.210   2.144054       23.77
#
#     test_acc@5
# 0        61.63
# 1        62.62
# 2        63.98
# 3        63.22
# 4        68.71
# ..         ...
# ...

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@5','test_acc@5'],use_index=True,
        kind="line", figsize=(5, 5))
plt.title('Supervised Top@5')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@1','test_acc@1'],use_index=True,
        kind="line", figsize=(5, 5))

plt.title('Supervised Top@1')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
df=pd.read_csv('./linear_statistics_supervised_vf.csv',header=0,names=['epoch','train_loss','train_acc@1','train_acc@5','test_loss','test_acc@1','test_acc@5'])

# %%
df
# Out:
#     epoch  train_loss  train_acc@1  train_acc@5  test_loss  test_acc@1  \
# 0       1    2.244554       15.540       64.082   2.219753       16.65
# 1       2    2.216261       17.734       67.924   2.220548       16.49
# 2       3    2.200108       19.172       70.070   2.190950       18.95
# 3       4    2.185519       20.308       71.792   2.179862       20.32
# 4       5    2.166481       22.618       73.452   2.158477       24.06
# ..    ...         ...          ...          ...        ...         ...
# 95     96    2.089321       30.500       81.006   2.099339       29.05
# 96     97    2.089357       30.520       81.282   2.101408       29.32
# 97     98    2.090370       30.504       80.824   2.105891       29.12
# 98     99    2.090719       30.164       81.122   2.102686       29.27
# 99    100    2.089501       30.390       81.124   2.101653       29.10
#
#     test_acc@5
# 0        68.56
# 1        69.00
# 2        72.59
# 3        72.39
# 4        73.08
# ..         ...
# ...

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@5','test_acc@5'],use_index=True,
        kind="line", figsize=(5, 5))
plt.title('Supervised Top@5')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@1','test_acc@1'],use_index=True,
        kind="line", figsize=(5, 5))

plt.title('Supervised Top@1')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
df=pd.read_csv('./linear_statistics_0.01.csv',header=0,names=['epoch','train_loss','train_acc@1','train_acc@5','test_loss','test_acc@1','test_acc@5'])

# %%
df
# Out:
#     epoch  train_loss  train_acc@1  train_acc@5  test_loss  test_acc@1  \
# 0       1    2.128891         32.6         73.8   1.902492       59.16
# 1       2    1.803552         71.4         98.2   1.785690       71.46
# 2       3    1.714972         81.2         98.4   1.735786       75.04
# 3       4    1.670632         84.2         99.2   1.712014       75.88
# 4       5    1.635023         86.2         99.2   1.697238       76.22
# ..    ...         ...          ...          ...        ...         ...
# 95     96    1.434553        100.0        100.0   1.688522       77.60
# 96     97    1.437657        100.0        100.0   1.682873       77.83
# 97     98    1.436718        100.0        100.0   1.679758       77.94
# 98     99    1.438707        100.0        100.0   1.686264       77.77
# 99    100    1.437970        100.0        100.0   1.679691       77.99
#
#     test_acc@5
# 0        94.36
# 1        97.19
# 2        98.13
# 3        97.75
# 4        97.67
# ..         ...
# ...

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@5','test_acc@5'],use_index=True,
        kind="line", figsize=(5, 5))
plt.title('Simclr Top@5 with 1% labelled data')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@1','test_acc@1'],use_index=True,
        kind="line", figsize=(5, 5))

plt.title('Simclr Top@1 with 1% labelled data')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
df=pd.read_csv('./linear_statistics_supervised_0.01.csv',header=0,names=['epoch','train_loss','train_acc@1','train_acc@5','test_loss','test_acc@1','test_acc@5'])

# %%
df
# Out:
#     epoch  train_loss  train_acc@1  train_acc@5  test_loss  test_acc@1  \
# 0       1    2.353827          9.8         49.2   2.346216       11.36
# 1       2    2.328798         10.0         51.8   2.340028        9.81
# 2       3    2.316323         10.0         51.4   2.329323       10.00
# 3       4    2.301271          9.8         54.2   2.320227       10.00
# 4       5    2.290987         10.6         58.0   2.313125        9.99
# ..    ...         ...          ...          ...        ...         ...
# 95     96    2.003932         42.2         87.2   2.218993       17.98
# 96     97    1.973716         46.6         90.4   2.221169       18.99
# 97     98    1.952264         49.4         89.6   2.199877       20.11
# 98     99    1.973046         46.8         91.0   2.217314       19.25
# 99    100    1.946904         51.2         91.0   2.215880       19.28
#
#     test_acc@5
# 0        49.98
# 1        49.93
# 2        50.00
# 3        50.00
# 4        50.00
# ..         ...
# ...

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@5','test_acc@5'],use_index=True,
        kind="line", figsize=(5, 5))
plt.title('Supervised Top@5 with 1% labelled data')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@1','test_acc@1'],use_index=True,
        kind="line", figsize=(5, 5))

plt.title('Supervised Top@1 with 1% labelled data')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
df=pd.read_csv('./linear_statistics_0.1.csv',header=0,names=['epoch','train_loss','train_acc@1','train_acc@5','test_loss','test_acc@1','test_acc@5'])

# %%
df
# Out:
#     epoch  train_loss  train_acc@1  train_acc@5  test_loss  test_acc@1  \
# 0       1    1.775890        70.94        94.52   1.657334       79.72
# 1       2    1.638039        81.76        98.44   1.636322       81.08
# 2       3    1.619826        83.14        98.64   1.622510       82.05
# 3       4    1.608493        84.06        98.92   1.618947       82.21
# 4       5    1.600354        84.72        99.22   1.614568       82.42
# ..    ...         ...          ...          ...        ...         ...
# 95     96    1.518852        94.28        99.94   1.608806       83.04
# 96     97    1.523863        93.88        99.94   1.610889       82.64
# 97     98    1.526238        93.70        99.92   1.607885       82.78
# 98     99    1.520129        94.24        99.96   1.606252       83.03
# 99    100    1.518588        94.24        99.90   1.613629       82.44
#
#     test_acc@5
# 0        98.65
# 1        98.30
# 2        98.65
# 3        98.87
# 4        98.61
# ..         ...
# ...

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@5','test_acc@5'],use_index=True,
        kind="line", figsize=(5, 5))
plt.title('simclr Top@5 with 10% labelled data')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@1','test_acc@1'],use_index=True,
        kind="line", figsize=(5, 5))

plt.title('Simclr Top@1 with 10% labelled data')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
df=pd.read_csv('./linear_statistics_supervised_0.1.csv',header=0,names=['epoch','train_loss','train_acc@1','train_acc@5','test_loss','test_acc@1','test_acc@5'])

# %%
df
# Out:
#     epoch  train_loss  train_acc@1  train_acc@5  test_loss  test_acc@1  \
# 0       1    2.336595        10.52        52.42   2.315656       10.07
# 1       2    2.275937        13.48        59.06   2.254007       14.78
# 2       3    2.250373        15.24        62.62   2.252806       16.08
# 3       4    2.235672        16.28        65.40   2.238787       16.25
# 4       5    2.243165        15.14        64.12   2.238306       13.85
# ..    ...         ...          ...          ...        ...         ...
# 95     96    2.096560        29.12        80.52   2.145012       24.49
# 96     97    2.083748        31.06        81.74   2.148804       24.81
# 97     98    2.085405        31.36        81.44   2.151744       24.16
# 98     99    2.093860        30.70        80.06   2.158222       22.03
# 99    100    2.098006        29.10        80.02   2.158914       22.92
#
#     test_acc@5
# 0        51.55
# 1        62.01
# 2        62.85
# 3        64.11
# 4        67.35
# ..         ...
# ...

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@5','test_acc@5'],use_index=True,
        kind="line", figsize=(5, 5))
plt.title('Supervised Top@5 with 10% labelled data')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams.update({'font.size': 10})
df.plot( y=['train_acc@1','test_acc@1'],use_index=True,
        kind="line", figsize=(5, 5))

plt.title('Supervised Top@1 with 10% labelled data')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
